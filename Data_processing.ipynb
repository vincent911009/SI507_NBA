# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Data processing for regular stats

# %%
players = pd.read_csv("players.csv")

# %%
del players["Unnamed: 0"]
del players["Rk"]
players["Player"] = players["Player"].str.replace("*", "", regex=False)

# %%
def single_row(df):
    if df.shape[0]==1:
        return df
    else:
        row = df[df["Tm"] == "TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row

# %%
players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
players.index = players.index.droplevel()
players.index = players.index.droplevel()
players[players["Player"] == "Greg Anderson"]
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 8     Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1
# 953   Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4
# 1452  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2
# 1922  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6
# 2489  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9
# 3082  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8     7.4  11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 953   5.0   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 1452  2.5   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 1922  1.5   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 2489  3.5   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# 3082  1.6   2.4  0.3  0.4  0.2  0.3  1.7   1.8  1998
#
# [6 rows x 30 columns]

# %% [markdown]
# Data Processing for advanced stats

# %%
advanced = pd.read_csv("advanced_data.csv")

# %%
del advanced["Unnamed: 0"]
del advanced["Unnamed: 19"]
del advanced["Unnamed: 24"]
del advanced["Rk"]

# %%
advanced["Player"] = advanced["Player"].str.replace("*", "", regex=False)
advanced = advanced.groupby(["Player", "Year"]).apply(single_row)
advanced.index = advanced.index.droplevel()
advanced.index = advanced.index.droplevel()

# %%
advanced[advanced["Player"] == "Greg Anderson"]
# Out:
#              Player Pos Age   Tm   G    MP   PER   TS%  3PAr   FTr  ...  USG%  \
# 8     Greg Anderson  PF  27  DEN  82  2793  12.6  .486  .005  .314  ...  17.1
# 953   Greg Anderson  PF  29  DET  77  1624  14.6  .561  .008  .416  ...  14.3
# 1452  Greg Anderson  PF  30  ATL  51   622  12.6  .547  .000  .683  ...  12.2
# 1922  Greg Anderson  PF  31  SAS  46   344   7.7  .466  .021  .532  ...  10.5
# 2489  Greg Anderson   C  32  SAS  82  1659  11.4  .531  .004  .355  ...  10.5
# 3082  Greg Anderson   C  33  ATL  50   398  10.4  .444  .062  .506  ...  13.5
#
#        OWS  DWS   WS WS/48  OBPM  DBPM   BPM  VORP  Year
# 8     -0.6  3.6  3.0  .052  -2.4  -1.1  -3.4  -1.0  1992
# 953    1.4  2.0  3.4  .101  -1.7   0.1  -1.6   0.2  1994
# 1452   0.3  1.3  1.5  .118  -3.9   1.7  -2.2   0.0  1995
# 1922  -0.3  0.7  0.4  .056  -6.2   2.6  -3.5  -0.1  1996
# 2489   0.7  1.5  2.2  .064  -3.6   0.1  -3.5  -0.6  1997
# 3082   0.0  0.7  0.7  .090  -4.3   0.9  -3.4  -0.1  1998
#
# [6 rows x 27 columns]

# %% [markdown]
# Merge data of regular stats and advanced stats

# %%
combined = players.merge(advanced, how="outer", on=["Player", "Year"])

# %%
combined.to_csv("Combined_stats.csv")
